# %% [markdown]
# #### Imports and stuff

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ## Average Path Length

# %%
# Example graph represented by its edges
edges = [(0, 1), (0, 2), (0, 3), (1, 4), (1, 5), (2, 5), (3, 6), (4, 7), (5, 8), (6, 8), (7, 9), (8, 9)]

# Create an undirected graph
G = nx.Graph()

# Add edges to the graph
G.add_edges_from(edges)

# Draw the graph
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color='black', linewidths=1, font_size=15)

# Display the graph
plt.title('Graph that used in "Average Path Length" calculation')
plt.show()

# %% [markdown]
# ## Average Clustering Coefficient

# %%
# Define the graph edges with high clustering
edges = [
    (0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3), 
    (4, 5), (4, 6), (4, 7), (5, 6), (5, 7), (6, 7), 
    (8, 9), (8, 10), (8, 11), (9, 10), (9, 11), (10, 11),
    (0, 4), (1, 5), (2, 6), (3, 7), (4, 8), (5, 9), (6, 10), (7, 11),
]

# Create a graph
G = nx.Graph()

# Add edges to the graph
G.add_edges_from(edges)

# Plot the graph
plt.figure(figsize=(8, 6))
nx.draw(G, with_labels=True, node_color='skyblue', node_size=800, font_size=10, font_weight='bold')
plt.title('Graph that used in "Average Clustering Coefficient" calculation')
plt.show()

# %% [markdown]
# ## Influence Simulation

# %%
# Define the edges of the graph
edges = [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (3, 5), (4, 5), (4, 6), (5, 6)]

# Create a directed graph
G = nx.Graph()

# Add edges to the graph
G.add_edges_from(edges)

# Plot the graph
pos = nx.spring_layout(G)  # Position nodes using Fruchterman-Reingold force-directed algorithm
nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=12, font_weight='bold')
plt.title('Graph that used in "Influence Simluation"')
plt.show()
